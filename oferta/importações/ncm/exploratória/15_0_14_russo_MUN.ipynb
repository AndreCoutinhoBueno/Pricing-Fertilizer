# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
n=imp_fert_ncm=pd.read_csv('~/git/BD/temp/imp_fert_ncm.csv')
n
# Out:
#         CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA   CO_URF  \
# 0         1997      12  31042090       10       23        RS       1  1015400
# 1         1997       3  31027000       10      249        SP       1   817800
# 2         1997      11  31042090       10      249        SP       4   817600
# 3         1997      12  31021010       10      831        SC       1   920151
# 4         1997       3  31022100       10       23        RJ       1   717600
# ...        ...     ...       ...      ...      ...       ...     ...      ...
# 103093    2024       1  31031100       10      474        PR       1   917800
# 103094    2024       6  31023000       10      676        RS       1  1017700
# 103095    2024       3  31042090       10      676        GO       1   317903
# 103096    2024       2  31021010       10      160        ES       1   717600
# 103097    2024       1  31059090       10      403        RS       1  1017700
#
# ...

# %%
ncm=pd.read_csv('~/git/BD/Comexstat/tab_complementares/NCM.csv',encoding='Latin-1',sep=';')
co_ncm_nsp=ncm[ncm.NO_NCM_POR.str.contains('Outros nitratos de sódio potássico')].CO_NCM.unique()[0]

# %%
co_ncm_nsp
# Out:
# np.int64(31059019)

# %%
nsp=n[n.CO_NCM==co_ncm_nsp]

# %%
pais=pd.read_csv('~/git/BD/Comexstat/tab_complementares/PAIS.csv',encoding='Latin-1',sep=';')[['CO_PAIS','CO_PAIS_ISOA3','NO_PAIS']]

# %%
nsp=nsp.merge(pais)

# %%
nsp_1=nsp[(nsp.NO_PAIS=='Rússia')&(nsp.CO_ANO>=2010)&(nsp.CO_ANO<=2013)].sort_values(by=['CO_ANO','CO_MES'])
nsp_1
# Out:
#      CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 94     2010       1  31059019       10      676        SP       1  917800
# 99     2010       1  31059019       10      676        PR       1  917800
# 95     2010       9  31059019       10      676        PR       1  917800
# 89     2010      10  31059019       10      676        SP       1  917800
# 88     2010      12  31059019       10      676        SP       1  917800
# 131    2011       7  31059019       10      676        PR       1  917800
# 136    2011       7  31059019       10      676        SP       1  917800
# 121    2011       9  31059019       10      676        SP       1  817800
# 133    2011       9  31059019       10      676        MG       1  817800
# 117    2011      10  31059019       10      676        SP       1  817800
# 106    2011      12  31059019       10      676        PR       1  917800
# 111    2011      12  31059019       10      676        GO       1  917800
# ...

# %%
mn_poly=pd.read_csv('~/git/BD/temp/mn_poly.csv')

# %%
mun=pd.read_csv('~/git/BD/Comexstat/tab_complementares/UF_MUN.csv',encoding='Latin-1',sep=';')

# %%
mun=mun.rename(columns={'CO_MUN_GEO':'CO_MUN'})

# %%
nsp_1.merge(mn_poly).merge(mun).groupby(by=['NO_MUN'])['KG_LIQUIDO'].sum().sort_values()
# Out:
# NO_MUN
# CAMPO GRANDE       1000000
# CASCAVEL           1000000
# CRISTALINA         1000000
# PATOS DE MINAS     3100000
# JUNDIAI            3300000
# OURINHOS           4400000
# MARINGA            6600000
# SORRISO            8025192
# CUBATAO           15000000
# RIBEIRAO PRETO    17433147
# PARANAGUA         27000000
# Name: KG_LIQUIDO, dtype: int64
