# %%
import time
inicio=time.time()

# %%
import numpy as np
import pandas as pd

# %%
imp_fert=pd.read_csv('~/git/BD/temp/imp_fert_quanti_g_ncm_uf.csv')

# %%
imp_fert=imp_fert.loc[:,:'KG_LIQUIDO']

# %% [raw]
# filt_ncm=imp_fert.groupby('CO_NCM').KG_LIQUIDO.sum().sort_values(ascending=False).head(2).reset_index().CO_NCM.values[:1]
# imp_fert=imp_fert[imp_fert.CO_NCM.isin(filt_ncm)]
#
# filt_uf=imp_fert.groupby('SG_UF_NCM').KG_LIQUIDO.sum().sort_values(ascending=False).head(2).reset_index().SG_UF_NCM.values[:1]
# imp_fert=imp_fert[imp_fert.SG_UF_NCM.isin(filt_uf)]

# %%
# %run '~/git/prev_score_ncm_uf.py'
# Out:
# Disponível função prev_score(ano_mes_ncm_uf)

# %%
imp_fert.head(1)
# Out:
#     sigla  CO_ANO  CO_MES       CO_NCM SG_UF_NCM  KG_LIQUIDO
# 0  MAP-hi    1997       2  31054000-hi        SP     1575000

# %%
q=prev_score(imp_fert)

# %%
q.to_csv('~/git/BD/temp/prev_score_quanti.csv',index=False)

# %%
fim=time.time()
d=fim-inicio
print(f'Duração:{round(d/60)} minutos.')
# Out:
# Duração:4 minutos.

# %%
q[['accuracy','precision','recall','r2']].mean()
# Out:
# accuracy      0.616194
# precision     0.721051
# recall        0.688652
# r2          -11.985133
# dtype: float64

# %%
q.head(1)
# Out:
#      CO_MES       CO_NCM SG_UF_NCM  accuracy  precision    recall        r2
# 5544      1  31021010-hi         0  0.685606   0.916168  0.689189  0.284114

# %%
round(q.groupby('CO_NCM')[q.columns[3:]].mean(),1)
# Out:
# /tmp/ipykernel_31674/2220920743.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   round(q.groupby('CO_NCM')[q.columns[3:]].mean(),1)
#              accuracy  precision  recall    r2
# CO_NCM
# 31021010-hi       0.6        0.8     0.7  -1.2
# 31022100-hi       0.6        0.8     0.6  -0.8
# 31023000-hi       0.5        0.4     0.5 -87.6
# 31042090-hi       0.6        0.9     0.6  -1.2
# 31052000-hi       0.7        0.6     0.9  -9.0
# 31054000-hi       0.7        0.9     0.7  -1.2
# 31055900-hi       0.6        0.7     0.8  -3.5

# %%
round(q.groupby('SG_UF_NCM')[q.columns[3:]].mean(),1)
# Out:
# /tmp/ipykernel_31674/92138848.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   round(q.groupby('SG_UF_NCM')[q.columns[3:]].mean(),1)
#            accuracy  precision  recall    r2
# SG_UF_NCM
# 0               0.6        0.7     0.8 -22.2
# BA              0.6        0.6     0.6 -10.6
# GO              0.6        0.8     0.7  -1.6
# MA              0.6        0.5     0.7  -0.8
# MG              0.7        0.9     0.7  -0.7
# MS              0.6        0.7     0.7 -15.8
# MT              0.6        0.7     0.7 -68.9
# PR              0.7        0.9     0.7  -0.9
# RS              0.6        0.7     0.7  -1.1
# SC              0.5        0.5     0.6  -5.0
# SP              0.6        0.9     0.7  -1.4

# %%
round(q.groupby('SG_UF_NCM')[q.columns[3:]].mean(),1)
# Out:
# /tmp/ipykernel_31674/92138848.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   round(q.groupby('SG_UF_NCM')[q.columns[3:]].mean(),1)
#            accuracy  precision  recall    r2
# SG_UF_NCM
# 0               0.6        0.7     0.8 -22.2
# BA              0.6        0.6     0.6 -10.6
# GO              0.6        0.8     0.7  -1.6
# MA              0.6        0.5     0.7  -0.8
# MG              0.7        0.9     0.7  -0.7
# MS              0.6        0.7     0.7 -15.8
# MT              0.6        0.7     0.7 -68.9
# PR              0.7        0.9     0.7  -0.9
# RS              0.6        0.7     0.7  -1.1
# SC              0.5        0.5     0.6  -5.0
# SP              0.6        0.9     0.7  -1.4

# %%
round(q.groupby('CO_MES')[q.columns[3:]].mean(),1)
# Out:
# /tmp/ipykernel_31674/3954593838.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   round(q.groupby('CO_MES')[q.columns[3:]].mean(),1)
#         accuracy  precision  recall    r2
# CO_MES
# 1            0.6        0.7     0.7 -12.0
# 2            0.6        0.7     0.7 -12.0
# 3            0.6        0.7     0.7 -12.0
# 4            0.6        0.7     0.7 -12.0
# 5            0.6        0.7     0.7 -12.0
# 6            0.6        0.7     0.7 -12.0
# 7            0.6        0.7     0.7 -12.0
# 8            0.6        0.7     0.7 -12.0
# 9            0.6        0.7     0.7 -12.0
# 10           0.6        0.7     0.7 -12.0
# 11           0.6        0.7     0.7 -12.0
# 12           0.6        0.7     0.7 -12.0
