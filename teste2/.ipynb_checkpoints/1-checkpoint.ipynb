# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
cx=pd.read_csv('/home/andre301267/git/BD/temp/imp_fert_ncm_quanti.csv').sort_values(by=['CO_ANO','CO_MES'])

# %%
cx.drop(columns=['CO_NCM','VL_FOB_orig','VL_FRETE_orig','VL_SEGURO_orig','VL_SEGURO'],inplace=True)

# %%
cx.columns
# Out:
# Index(['CO_ANO', 'CO_MES', 'nick', 'UF', 'CO_PAIS', 'CO_URF', 'KG_LIQUIDO',
#        'VL_FOB', 'VL_FRETE', 'km'],
#       dtype='object')

# %%
nick=['MOP']
km=[2]
UF=['BA']
CO_PAIS=[]
CO_URF=[]

# %%
cat_list=['nick','km','UF','CO_PAIS','CO_URF']
cat_dict={'nick':nick,'km':km,'UF':UF,'CO_PAIS':CO_PAIS,'CO_URF':CO_URF}

# %%
for col in cat_list:
    if len(cat_dict[col])>0:
        cx=cx[cx[col].isin(cat_dict[col])]
    else:
        cx.drop(columns=[col],inplace=True)

# %%
col_cat=[x for x in ['nick','km','UF','CO_PAIS','CO_URF'] if x in cx.columns]

col_quanti=['KG_LIQUIDO','VL_FOB','VL_FRETE']

cx=cx.groupby(by=['CO_ANO','CO_MES']+col_cat)[col_quanti].sum().reset_index()

# %%
cx
# Out:
#      CO_ANO  CO_MES nick  km  UF   KG_LIQUIDO      VL_FOB  VL_FRETE
# 0      1997       8  MOP   2  BA   10823780.0   2778760.0    259776
# 1      1997      10  MOP   2  BA   17244625.0   4537242.0    411964
# 2      1997      11  MOP   2  BA   10742193.0   2905814.0    252000
# 3      1997      12  MOP   2  BA    8708794.0   2407828.0    208800
# 4      1998       4  MOP   2  BA    8049864.0   2160464.0    192000
# ..      ...     ...  ...  ..  ..          ...         ...       ...
# 232    2024       4  MOP   2  BA   58217498.0  16883537.0   2992481
# 233    2024       5  MOP   2  BA  153941436.0  44040086.0   6898023
# 234    2024       6  MOP   2  BA  132817877.0  35560778.0   5659910
# 235    2024       7  MOP   2  BA   64989199.0  20942751.0   2927514
# 236    2024       8  MOP   2  BA   73074320.0  18784784.0   3138905
#
# [237 rows x 8 columns]

# %%
# %run '/home/andre301267/git/BD/Comexstat/function/matriz_esparsa.ipynb'
# Out:
# ** Função matriz_esparsa(comex_df) disponível **

# %%
cx=matriz_esparsa(cx)
cx
# Out:
#      CO_ANO  CO_MES       date nick  km  UF  KG_LIQUIDO    VL_FOB  VL_FRETE
# 0      1997       8 1997-08-01  MOP   2  BA    10823780   2778760    259776
# 1      1997       9 1997-09-01    0   0   0           0         0         0
# 2      1997      10 1997-10-01  MOP   2  BA    17244625   4537242    411964
# 3      1997      11 1997-11-01  MOP   2  BA    10742193   2905814    252000
# 4      1997      12 1997-12-01  MOP   2  BA     8708794   2407828    208800
# ..      ...     ...        ...  ...  ..  ..         ...       ...       ...
# 320    2024       4 2024-04-01  MOP   2  BA    58217498  16883537   2992481
# 321    2024       5 2024-05-01  MOP   2  BA   153941436  44040086   6898023
# 322    2024       6 2024-06-01  MOP   2  BA   132817877  35560778   5659910
# 323    2024       7 2024-07-01  MOP   2  BA    64989199  20942751   2927514
# 324    2024       8 2024-08-01  MOP   2  BA    73074320  18784784   3138905
#
# [325 rows x 9 columns]

# %%
cx=cx.assign(tipo='train')

# %%
cx_train=cx[cx.tipo=='train']

# %%
cx_prev=cx[cx.date==cx.date.max()]

# %%
cx_prev.CO_MES=cx_prev.CO_MES+1

# %%
cx_prev.CO_MES.values>0
# Out:
# array([ True])

# %%
if cx_prev.CO_MES.values>12:
    cx_prev.CO_ANO=cx_prev.CO_ANO+1
    cx_prev.CO_MES=1

# %%
cx=pd.concat([cx_train,cx_prev.assign(tipo='prev')])

# %%
cx
# Out:
#      CO_ANO  CO_MES       date nick  km  UF  KG_LIQUIDO    VL_FOB  VL_FRETE  \
# 0      1997       8 1997-08-01  MOP   2  BA    10823780   2778760    259776
# 1      1997       9 1997-09-01    0   0   0           0         0         0
# 2      1997      10 1997-10-01  MOP   2  BA    17244625   4537242    411964
# 3      1997      11 1997-11-01  MOP   2  BA    10742193   2905814    252000
# 4      1997      12 1997-12-01  MOP   2  BA     8708794   2407828    208800
# ..      ...     ...        ...  ...  ..  ..         ...       ...       ...
# 321    2024       5 2024-05-01  MOP   2  BA   153941436  44040086   6898023
# 322    2024       6 2024-06-01  MOP   2  BA   132817877  35560778   5659910
# 323    2024       7 2024-07-01  MOP   2  BA    64989199  20942751   2927514
# 324    2024       8 2024-08-01  MOP   2  BA    73074320  18784784   3138905
# 324    2024       9 2024-08-01  MOP   2  BA    73074320  18784784   3138905
#
#       tipo
# 0    train
# 1    train
# 2    train
# 3    train
# 4    train
# ..     ...
# 321  train
# 322  train
# 323  train
# 324  train
# 324   prev
#
# [326 rows x 10 columns]

# %%
cx.date=cx.date.astype(int)

# %% [markdown]
# # Previsão

# %%
cx
# Out:
#      CO_ANO  CO_MES                 date nick  km  UF  KG_LIQUIDO    VL_FOB  \
# 0      1997       8   870393600000000000  MOP   2  BA    10823780   2778760
# 1      1997       9   873072000000000000    0   0   0           0         0
# 2      1997      10   875664000000000000  MOP   2  BA    17244625   4537242
# 3      1997      11   878342400000000000  MOP   2  BA    10742193   2905814
# 4      1997      12   880934400000000000  MOP   2  BA     8708794   2407828
# ..      ...     ...                  ...  ...  ..  ..         ...       ...
# 321    2024       5  1714521600000000000  MOP   2  BA   153941436  44040086
# 322    2024       6  1717200000000000000  MOP   2  BA   132817877  35560778
# 323    2024       7  1719792000000000000  MOP   2  BA    64989199  20942751
# 324    2024       8  1722470400000000000  MOP   2  BA    73074320  18784784
# 324    2024       9  1722470400000000000  MOP   2  BA    73074320  18784784
#
#      VL_FRETE   tipo
# 0      259776  train
# 1           0  train
# 2      411964  train
# 3      252000  train
# 4      208800  train
# ..        ...    ...
# 321   6898023  train
# 322   5659910  train
# 323   2927514  train
# 324   3138905  train
# 324   3138905   prev
#
# [326 rows x 10 columns]

# %%
cx[cx.tipo=='prev'].date=pd.to_datetime(cx[cx.tipo=='prev'].CO_ANO.astype(str)+'/'+cx[cx.tipo=='prev'].CO_MES.astype(str)+'/1').astype(int)

# %%
cx
# Out:
#      CO_ANO  CO_MES                 date nick  km  UF  KG_LIQUIDO    VL_FOB  \
# 0      1997       8   870393600000000000  MOP   2  BA    10823780   2778760
# 1      1997       9   873072000000000000    0   0   0           0         0
# 2      1997      10   875664000000000000  MOP   2  BA    17244625   4537242
# 3      1997      11   878342400000000000  MOP   2  BA    10742193   2905814
# 4      1997      12   880934400000000000  MOP   2  BA     8708794   2407828
# ..      ...     ...                  ...  ...  ..  ..         ...       ...
# 321    2024       5  1714521600000000000  MOP   2  BA   153941436  44040086
# 322    2024       6  1717200000000000000  MOP   2  BA   132817877  35560778
# 323    2024       7  1719792000000000000  MOP   2  BA    64989199  20942751
# 324    2024       8  1722470400000000000  MOP   2  BA    73074320  18784784
# 324    2024       9  1722470400000000000  MOP   2  BA    73074320  18784784
#
#      VL_FRETE   tipo
# 0      259776  train
# 1           0  train
# 2      411964  train
# 3      252000  train
# 4      208800  train
# ..        ...    ...
# 321   6898023  train
# 322   5659910  train
# 323   2927514  train
# 324   3138905  train
# 324   3138905   prev
#
# [326 rows x 10 columns]

# %% [markdown]
# # Calssificação

# %%
# Marca ocorrências
cx=cx.assign(oc=0)
cx.loc[cx.KG_LIQUIDO>0,'oc']=1
cx.loc[cx.tipo=='prev',col_quanti+['oc']]=np.nan
prev=cx[cx.tipo=='prev']
cx.loc[cx.tipo=='prev','date']=pd.to_datetime(prev.CO_ANO.astype(str)+'/'+prev.CO_MES.astype(str)+'/1').astype(int)

# %%
cx
# Out:
#      CO_ANO  CO_MES                 date nick  km  UF   KG_LIQUIDO  \
# 0      1997       8   870393600000000000  MOP   2  BA   10823780.0
# 1      1997       9   873072000000000000    0   0   0          0.0
# 2      1997      10   875664000000000000  MOP   2  BA   17244625.0
# 3      1997      11   878342400000000000  MOP   2  BA   10742193.0
# 4      1997      12   880934400000000000  MOP   2  BA    8708794.0
# ..      ...     ...                  ...  ...  ..  ..          ...
# 321    2024       5  1714521600000000000  MOP   2  BA  153941436.0
# 322    2024       6  1717200000000000000  MOP   2  BA  132817877.0
# 323    2024       7  1719792000000000000  MOP   2  BA   64989199.0
# 324    2024       8  1722470400000000000  MOP   2  BA   73074320.0
# 324    2024       9  1725148800000000000  MOP   2  BA          NaN
#
#          VL_FOB   VL_FRETE   tipo   oc
# 0     2778760.0   259776.0  train  1.0
# 1           0.0        0.0  train  0.0
# 2     4537242.0   411964.0  train  1.0
# 3     2905814.0   252000.0  train  1.0
# 4     2407828.0   208800.0  train  1.0
# ..          ...        ...    ...  ...
# 321  44040086.0  6898023.0  train  1.0
# 322  35560778.0  5659910.0  train  1.0
# 323  20942751.0  2927514.0  train  1.0
# 324  18784784.0  3138905.0  train  1.0
# 324         NaN        NaN   prev  NaN
#
# [326 rows x 11 columns]

# %%
cx[['CO_MES']+col_cat+['tipo']]=cx[['CO_MES']+col_cat+['tipo']].astype('category')

# %%
cx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 326 entries, 0 to 324
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CO_ANO      326 non-null    int64
#  1   CO_MES      326 non-null    category
#  2   date        326 non-null    int64
#  3   nick        326 non-null    category
#  4   km          326 non-null    category
#  5   UF          326 non-null    category
#  6   KG_LIQUIDO  325 non-null    float64
#  7   VL_FOB      325 non-null    float64
#  8   VL_FRETE    325 non-null    float64
#  9   tipo        326 non-null    category
#  10  oc          325 non-null    float64
# dtypes: category(5), float64(4), int64(2)
# memory usage: 20.3 KB

# %%
cx=pd.get_dummies(cx)

# %% [markdown]
# # Classificação

# %%
train=cx[cx.tipo_train==True]
train
# Out:
#      CO_ANO                 date   KG_LIQUIDO      VL_FOB   VL_FRETE   oc  \
# 0      1997   870393600000000000   10823780.0   2778760.0   259776.0  1.0
# 1      1997   873072000000000000          0.0         0.0        0.0  0.0
# 2      1997   875664000000000000   17244625.0   4537242.0   411964.0  1.0
# 3      1997   878342400000000000   10742193.0   2905814.0   252000.0  1.0
# 4      1997   880934400000000000    8708794.0   2407828.0   208800.0  1.0
# ..      ...                  ...          ...         ...        ...  ...
# 320    2024  1711929600000000000   58217498.0  16883537.0  2992481.0  1.0
# 321    2024  1714521600000000000  153941436.0  44040086.0  6898023.0  1.0
# 322    2024  1717200000000000000  132817877.0  35560778.0  5659910.0  1.0
# 323    2024  1719792000000000000   64989199.0  20942751.0  2927514.0  1.0
# 324    2024  1722470400000000000   73074320.0  18784784.0  3138905.0  1.0
#
#      CO_MES_1  CO_MES_2  CO_MES_3  CO_MES_4  ...  CO_MES_11  CO_MES_12  \
# 0       False     False     False     False  ...      False      False
# 1       False     False     False     False  ...      False      False
# 2       False     False     False     False  ...      False      False
# 3       False     False     False     False  ...       True      False
# 4       False     False     False     False  ...      False       True
# ..        ...       ...       ...       ...  ...        ...        ...
# 320     False     False     False      True  ...      False      False
# 321     False     False     False     False  ...      False      False
# 322     False     False     False     False  ...      False      False
# 323     False     False     False     False  ...      False      False
# 324     False     False     False     False  ...      False      False
#
#      nick_0  nick_MOP   km_0   km_2   UF_0  UF_BA  tipo_prev  tipo_train
# 0     False      True  False   True  False   True      False        True
# 1      True     False   True  False   True  False      False        True
# 2     False      True  False   True  False   True      False        True
# 3     False      True  False   True  False   True      False        True
# 4     False      True  False   True  False   True      False        True
# ..      ...       ...    ...    ...    ...    ...        ...         ...
# 320   False      True  False   True  False   True      False        True
# 321   False      True  False   True  False   True      False        True
# 322   False      True  False   True  False   True      False        True
# 323   False      True  False   True  False   True      False        True
# 324   False      True  False   True  False   True      False        True
#
# [325 rows x 26 columns]

# %%
X_train=train[['date']+train.select_dtypes('bool').columns.tolist()]

# %%
X_train
# Out:
#                     date  CO_MES_1  CO_MES_2  CO_MES_3  CO_MES_4  CO_MES_5  \
# 0     870393600000000000     False     False     False     False     False
# 1     873072000000000000     False     False     False     False     False
# 2     875664000000000000     False     False     False     False     False
# 3     878342400000000000     False     False     False     False     False
# 4     880934400000000000     False     False     False     False     False
# ..                   ...       ...       ...       ...       ...       ...
# 320  1711929600000000000     False     False     False      True     False
# 321  1714521600000000000     False     False     False     False      True
# 322  1717200000000000000     False     False     False     False     False
# 323  1719792000000000000     False     False     False     False     False
# 324  1722470400000000000     False     False     False     False     False
#
#      CO_MES_6  CO_MES_7  CO_MES_8  CO_MES_9  ...  CO_MES_11  CO_MES_12  \
# 0       False     False      True     False  ...      False      False
# 1       False     False     False      True  ...      False      False
# 2       False     False     False     False  ...      False      False
# 3       False     False     False     False  ...       True      False
# 4       False     False     False     False  ...      False       True
# ..        ...       ...       ...       ...  ...        ...        ...
# 320     False     False     False     False  ...      False      False
# 321     False     False     False     False  ...      False      False
# 322      True     False     False     False  ...      False      False
# 323     False      True     False     False  ...      False      False
# 324     False     False      True     False  ...      False      False
#
#      nick_0  nick_MOP   km_0   km_2   UF_0  UF_BA  tipo_prev  tipo_train
# 0     False      True  False   True  False   True      False        True
# 1      True     False   True  False   True  False      False        True
# 2     False      True  False   True  False   True      False        True
# 3     False      True  False   True  False   True      False        True
# 4     False      True  False   True  False   True      False        True
# ..      ...       ...    ...    ...    ...    ...        ...         ...
# 320   False      True  False   True  False   True      False        True
# 321   False      True  False   True  False   True      False        True
# 322   False      True  False   True  False   True      False        True
# 323   False      True  False   True  False   True      False        True
# 324   False      True  False   True  False   True      False        True
#
# [325 rows x 21 columns]

# %%
y_train=train.oc
y_train
# Out:
# 0      1.0
# 1      0.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 320    1.0
# 321    1.0
# 322    1.0
# 323    1.0
# 324    1.0
# Name: oc, Length: 325, dtype: float64

# %%
prev=cx[cx.tipo_prev==True]
prev
# Out:
#      CO_ANO                 date  KG_LIQUIDO  VL_FOB  VL_FRETE  oc  CO_MES_1  \
# 324    2024  1725148800000000000         NaN     NaN       NaN NaN     False
#
#      CO_MES_2  CO_MES_3  CO_MES_4  ...  CO_MES_11  CO_MES_12  nick_0  \
# 324     False     False     False  ...      False      False   False
#
#      nick_MOP   km_0  km_2   UF_0  UF_BA  tipo_prev  tipo_train
# 324      True  False  True  False   True       True       False
#
# [1 rows x 26 columns]

# %%
X_prev=prev[['date']+prev.select_dtypes('bool').columns.tolist()]
X_prev
# Out:
#                     date  CO_MES_1  CO_MES_2  CO_MES_3  CO_MES_4  CO_MES_5  \
# 324  1725148800000000000     False     False     False     False     False
#
#      CO_MES_6  CO_MES_7  CO_MES_8  CO_MES_9  ...  CO_MES_11  CO_MES_12  \
# 324     False     False     False      True  ...      False      False
#
#      nick_0  nick_MOP   km_0  km_2   UF_0  UF_BA  tipo_prev  tipo_train
# 324   False      True  False  True  False   True       True       False
#
# [1 rows x 21 columns]

# %%
from sklearn.ensemble import RandomForestClassifier as RFC
RFC=RFC()

# %%
RFC.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
X_prev=X_prev.assign(oc=RFC.predict(X_prev))
X_prev
# Out:
#                     date  CO_MES_1  CO_MES_2  CO_MES_3  CO_MES_4  CO_MES_5  \
# 324  1725148800000000000     False     False     False     False     False
#
#      CO_MES_6  CO_MES_7  CO_MES_8  CO_MES_9  ...  CO_MES_12  nick_0  nick_MOP  \
# 324     False     False     False      True  ...      False   False      True
#
#       km_0  km_2   UF_0  UF_BA  tipo_prev  tipo_train   oc
# 324  False  True  False   True       True       False  1.0
#
# [1 rows x 22 columns]

# %% [markdown]
# # Regressão

# %%
train=train[train.oc==1]

# %%
X_train=train[['date']+train.select_dtypes('bool').columns.tolist()]

# %%
X_train
# Out:
#                     date  CO_MES_1  CO_MES_2  CO_MES_3  CO_MES_4  CO_MES_5  \
# 0     870393600000000000     False     False     False     False     False
# 2     875664000000000000     False     False     False     False     False
# 3     878342400000000000     False     False     False     False     False
# 4     880934400000000000     False     False     False     False     False
# 8     891388800000000000     False     False     False      True     False
# ..                   ...       ...       ...       ...       ...       ...
# 320  1711929600000000000     False     False     False      True     False
# 321  1714521600000000000     False     False     False     False      True
# 322  1717200000000000000     False     False     False     False     False
# 323  1719792000000000000     False     False     False     False     False
# 324  1722470400000000000     False     False     False     False     False
#
#      CO_MES_6  CO_MES_7  CO_MES_8  CO_MES_9  ...  CO_MES_11  CO_MES_12  \
# 0       False     False      True     False  ...      False      False
# 2       False     False     False     False  ...      False      False
# 3       False     False     False     False  ...       True      False
# 4       False     False     False     False  ...      False       True
# 8       False     False     False     False  ...      False      False
# ..        ...       ...       ...       ...  ...        ...        ...
# 320     False     False     False     False  ...      False      False
# 321     False     False     False     False  ...      False      False
# 322      True     False     False     False  ...      False      False
# 323     False      True     False     False  ...      False      False
# 324     False     False      True     False  ...      False      False
#
#      nick_0  nick_MOP   km_0  km_2   UF_0  UF_BA  tipo_prev  tipo_train
# 0     False      True  False  True  False   True      False        True
# 2     False      True  False  True  False   True      False        True
# 3     False      True  False  True  False   True      False        True
# 4     False      True  False  True  False   True      False        True
# 8     False      True  False  True  False   True      False        True
# ..      ...       ...    ...   ...    ...    ...        ...         ...
# 320   False      True  False  True  False   True      False        True
# 321   False      True  False  True  False   True      False        True
# 322   False      True  False  True  False   True      False        True
# 323   False      True  False  True  False   True      False        True
# 324   False      True  False  True  False   True      False        True
#
# [237 rows x 21 columns]

# %%
y_train=train[col_quanti]

# %%
y_train
# Out:
#       KG_LIQUIDO      VL_FOB   VL_FRETE
# 0     10823780.0   2778760.0   259776.0
# 2     17244625.0   4537242.0   411964.0
# 3     10742193.0   2905814.0   252000.0
# 4      8708794.0   2407828.0   208800.0
# 8      8049864.0   2160464.0   192000.0
# ..           ...         ...        ...
# 320   58217498.0  16883537.0  2992481.0
# 321  153941436.0  44040086.0  6898023.0
# 322  132817877.0  35560778.0  5659910.0
# 323   64989199.0  20942751.0  2927514.0
# 324   73074320.0  18784784.0  3138905.0
#
# [237 rows x 3 columns]

# %%
X_prev=X_prev[X_prev.oc==1].drop(columns='oc')

# %%
X_prev
# Out:
#                     date  CO_MES_1  CO_MES_2  CO_MES_3  CO_MES_4  CO_MES_5  \
# 324  1725148800000000000     False     False     False     False     False
#
#      CO_MES_6  CO_MES_7  CO_MES_8  CO_MES_9  ...  CO_MES_11  CO_MES_12  \
# 324     False     False     False      True  ...      False      False
#
#      nick_0  nick_MOP   km_0  km_2   UF_0  UF_BA  tipo_prev  tipo_train
# 324   False      True  False  True  False   True       True       False
#
# [1 rows x 21 columns]

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
RFR=RFR()

# %%
X_train
# Out:
#                     date  CO_MES_1  CO_MES_2  CO_MES_3  CO_MES_4  CO_MES_5  \
# 0     870393600000000000     False     False     False     False     False
# 2     875664000000000000     False     False     False     False     False
# 3     878342400000000000     False     False     False     False     False
# 4     880934400000000000     False     False     False     False     False
# 8     891388800000000000     False     False     False      True     False
# ..                   ...       ...       ...       ...       ...       ...
# 320  1711929600000000000     False     False     False      True     False
# 321  1714521600000000000     False     False     False     False      True
# 322  1717200000000000000     False     False     False     False     False
# 323  1719792000000000000     False     False     False     False     False
# 324  1722470400000000000     False     False     False     False     False
#
#      CO_MES_6  CO_MES_7  CO_MES_8  CO_MES_9  ...  CO_MES_11  CO_MES_12  \
# 0       False     False      True     False  ...      False      False
# 2       False     False     False     False  ...      False      False
# 3       False     False     False     False  ...       True      False
# 4       False     False     False     False  ...      False       True
# 8       False     False     False     False  ...      False      False
# ..        ...       ...       ...       ...  ...        ...        ...
# 320     False     False     False     False  ...      False      False
# 321     False     False     False     False  ...      False      False
# 322      True     False     False     False  ...      False      False
# 323     False      True     False     False  ...      False      False
# 324     False     False      True     False  ...      False      False
#
#      nick_0  nick_MOP   km_0  km_2   UF_0  UF_BA  tipo_prev  tipo_train
# 0     False      True  False  True  False   True      False        True
# 2     False      True  False  True  False   True      False        True
# 3     False      True  False  True  False   True      False        True
# 4     False      True  False  True  False   True      False        True
# 8     False      True  False  True  False   True      False        True
# ..      ...       ...    ...   ...    ...    ...        ...         ...
# 320   False      True  False  True  False   True      False        True
# 321   False      True  False  True  False   True      False        True
# 322   False      True  False  True  False   True      False        True
# 323   False      True  False  True  False   True      False        True
# 324   False      True  False  True  False   True      False        True
#
# [237 rows x 21 columns]

# %%
y_train
# Out:
#       KG_LIQUIDO      VL_FOB   VL_FRETE
# 0     10823780.0   2778760.0   259776.0
# 2     17244625.0   4537242.0   411964.0
# 3     10742193.0   2905814.0   252000.0
# 4      8708794.0   2407828.0   208800.0
# 8      8049864.0   2160464.0   192000.0
# ..           ...         ...        ...
# 320   58217498.0  16883537.0  2992481.0
# 321  153941436.0  44040086.0  6898023.0
# 322  132817877.0  35560778.0  5659910.0
# 323   64989199.0  20942751.0  2927514.0
# 324   73074320.0  18784784.0  3138905.0
#
# [237 rows x 3 columns]

# %%
RFR.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
RFR.predict(X_prev)
# Out:
# array([[87812472.85, 24662152.66,  3813152.98]])
