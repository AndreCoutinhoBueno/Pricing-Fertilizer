# %%
# Importa as bibliotecas necessárias
# %run '~/git/Bibliotecas.ipynb'

# %% [markdown]
# ### 1.Fertilizantes
#
# O foco do projeto são as importações através das Unidades da Receita Federal, consequentemente através dos portos de Salvador e Aratu na Bahia e destinadas a empresas importadoras sediadas nesta mesma Unidade Federativa.

# %%
urf=pd.read_csv('~/git/BD/Comexstat/URF.csv',encoding='Latin-1',sep=';')
urf_salvador_aratu=urf[(urf.NO_URF.str.contains('ARATU'))|(urf.NO_URF.str.contains('SALVADOR'))].CO_URF
urf_salvador_aratu
# Out:
# 47     517600
# 64     517700
# 65     517602
# 157    510100
# 162    517800
# 163    517801
# Name: CO_URF, dtype: int64

# %%
i=pd.read_csv('~/git/Pricing-Fertilizer-take-Rains-into-account/temp/imp1.csv')
i=i[(i.CO_URF.isin(urf_salvador_aratu))&(i.SG_UF_NCM=='BA')]
i.head()
# Out:
#      CO_ANO  CO_MES    CO_NCM  CO_UNID  CO_PAIS SG_UF_NCM  CO_VIA  CO_URF  \
# 25     1997       1  31042090       10       23        BA       1  517600
# 84     1997       2  31043010       10      383        BA       1  517600
# 116    1997       3  31022100       10      249        BA       1  510100
# 117    1997       3  31022100       10      249        BA       1  517600
# 132    1997       3  31029000       10      383        BA       1  517600
#
#      QT_ESTAT  KG_LIQUIDO  VL_FOB  VL_FRETE  VL_SEGURO
# 25         59       59400   10128      5824         41
# 84         63       62950   25180      4950          0
# 116   4003056     4003056  385794     72000       1574
# 117   2000000     2001528  194148     36000       1393
# 132     21300       21300    8658      1475          0

# %% [markdown]
# Como a coluna SG_UF_NCM ficou apenas com uma única categoria, 'BA', e como não há perspectiva de aproveitar a informação sobre unidade de  Receita Federal, essas duas colunas serão descartadas.

# %%
i.groupby('CO_VIA')['KG_LIQUIDO'].sum().sort_values()
# Out:
# CO_VIA
# 4            201
# 1    22033169330
# Name: KG_LIQUIDO, dtype: int64

# %%
i.groupby('CO_UNID')['KG_LIQUIDO'].sum().sort_values()
# Out:
# CO_UNID
# 10    22033169531
# Name: KG_LIQUIDO, dtype: int64

# %% [markdown]
# Como as colunas 'CO_VIA' e 'CO_UNID' apresentam praticamente todos os valores em uma única categoria, elas serão também  descartadas.
#
# A coluna 'QT_STAT' representa a quantidade importada medidas em outras unidades de que não sejam o 'KG_LIQUIDO'. Isso não é de interesse do projeto e a coluna também será descartada.

# %%
i.drop(columns=['SG_UF_NCM','CO_URF','CO_UNID','CO_VIA','QT_ESTAT'], inplace=True)

# %%
i.head()
# Out:
#      CO_ANO  CO_MES    CO_NCM  CO_PAIS  KG_LIQUIDO  VL_FOB  VL_FRETE  \
# 25     1997       1  31042090       23       59400   10128      5824
# 84     1997       2  31043010      383       62950   25180      4950
# 116    1997       3  31022100      249     4003056  385794     72000
# 117    1997       3  31022100      249     2001528  194148     36000
# 132    1997       3  31029000      383       21300    8658      1475
#
#      VL_SEGURO
# 25          41
# 84           0
# 116       1574
# 117       1393
# 132          0

# %%
i.duplicated().sum()
# Out:
# 0

# %%
i.isna().sum()
# Out:
# CO_ANO        0
# CO_MES        0
# CO_NCM        0
# CO_PAIS       0
# KG_LIQUIDO    0
# VL_FOB        0
# VL_FRETE      0
# VL_SEGURO     0
# dtype: int64

# %% [markdown]
# O arquivo não contém duplicatas nem celulas vazias ou inválidas.

# %%
i[i.KG_LIQUIDO<=0]
# Out:
#        CO_ANO  CO_MES    CO_NCM  CO_PAIS  KG_LIQUIDO  VL_FOB  VL_FRETE  \
# 10049    2002       4  31042090      767           0      70         0
# 15426    2004       5  31042090      249           0     230         8
#
#        VL_SEGURO
# 10049          0
# 15426          0

# %%
i[i.VL_FOB<=0]
# Out:
# Empty DataFrame
# Columns: [CO_ANO, CO_MES, CO_NCM, CO_PAIS, KG_LIQUIDO, VL_FOB, VL_FRETE, VL_SEGURO]
# Index: []

# %% [markdown]
# O arquivo possui dois registros sem peso maior que zero. Estes mesmos registros apresentam valor FOB irrisório e por isso serão descatados.

# %%
i=i[i.KG_LIQUIDO>0]

# %% [markdown]
# Numa primeira tentativa de atingir o objetivo, não levaremos em análise os diferentes NCMs e países de origem do registro de importação. Assim, a coluna 'CO_NCM' e 'CO_PAIS' serão descrtadas e os valores agrupados. Os valores monetários também serao descartados.

# %%
i=i.groupby(by=['CO_ANO','CO_MES'])['KG_LIQUIDO'].sum().reset_index()

# %% [raw]
# sns.displot(data=i,x='KG_LIQUIDO',log_scale=True).fig.suptitle('Importação de Fertilizantes na Bahia',y=1.01)
# plt.show()

# %% [markdown]
# Os valores menores do que 10**6.3 serão descartados.

# %%
i=i[i.KG_LIQUIDO>10**6.3]

# %% [markdown]
# Um registro apresenta peso muito acima da normalidade.

# %%
i[i.KG_LIQUIDO==i.KG_LIQUIDO.max()]
# Out:
#     CO_ANO  CO_MES  KG_LIQUIDO
# 78    2003       8  1420253045

# %% [markdown]
# Ele será substituido pela interpolação dos valores do mês no ano anterior e posterior ao ocorrido.

# %%
ano_erro=i[i.KG_LIQUIDO==i.KG_LIQUIDO.max()].CO_ANO.values[0]

ano_corr_anterior=i[i.CO_ANO==ano_erro+1].CO_ANO.values[0]

ano_corr_posterior=i[i.CO_ANO==ano_erro-1].CO_ANO.values[0]

mes_erro=i[i.KG_LIQUIDO==i.KG_LIQUIDO.max()].CO_MES.values[0]

val_corr=i[i.CO_ANO.isin([ano_corr_anterior,ano_corr_posterior])].KG_LIQUIDO.mean()

i.loc[i.KG_LIQUIDO==i.KG_LIQUIDO.max(),'KG_LIQUIDO']=val_corr

# %% [raw]
# sns.displot(data=i,x='KG_LIQUIDO',log_scale=True, bins=6).fig.suptitle('Importação de Fertilizantes na Bahia',y=1.01)
# plt.show()

# %% [raw]
# sns.displot(data=i,x='KG_LIQUIDO',log_scale=True,col='CO_MES',col_wrap=4, bins=6).fig.suptitle('Importação de Fertilizantes na Bahia',y=1.01)
# plt.show()

# %%
i['date']=pd.to_datetime(i.CO_ANO.astype(str)+'/'+i.CO_MES.astype(str)+'/1')

# %% [raw]
# sns.relplot(data=i,x='date',y='KG_LIQUIDO',col='CO_MES',col_wrap=4).fig.suptitle('Importação de Fertilizantes na Bahia',y=1.01)
# plt.show()

# %%
# Martiz Esparsa
i_ini=i.date.min()
i_fim=i.date.max()
i[['CO_ANO','CO_MES']]=i[['CO_ANO','CO_MES']].astype('category')
i2=i.groupby(by=['CO_ANO','CO_MES']).KG_LIQUIDO.sum().reset_index()
i2['date']=pd.to_datetime(i2.CO_ANO.astype(str)+'/'+i2.CO_MES.astype(str)+'/1')
i2=i2[(i2.date>=i_ini)&(i2.date<=i_fim)]
i2
# Out:
#     CO_ANO CO_MES   KG_LIQUIDO       date
# 2     1997      3    7505776.0 1997-03-01
# 3     1997      4   22660177.0 1997-04-01
# 4     1997      5   19598019.0 1997-05-01
# 5     1997      6   17594350.0 1997-06-01
# 6     1997      7   14261348.0 1997-07-01
# ..     ...    ...          ...        ...
# 320   2023      9  172570477.0 2023-09-01
# 321   2023     10  240914358.0 2023-10-01
# 322   2023     11   90119779.0 2023-11-01
# 323   2023     12  128496690.0 2023-12-01
# 324   2024      1  121343414.0 2024-01-01
#
# [323 rows x 4 columns]

# %%
i2['KG_fit']=np.poly1d(np.polyfit(i2.date.astype(int),i2.KG_LIQUIDO, deg=1))(i2.date.astype(int))
i2['KG_resi']=i2.KG_LIQUIDO-i2.KG_fit
i2
# Out:
#     CO_ANO CO_MES   KG_LIQUIDO       date        KG_fit       KG_resi
# 2     1997      3    7505776.0 1997-03-01  8.615051e+06 -1.109275e+06
# 3     1997      4   22660177.0 1997-04-01  8.964945e+06  1.369523e+07
# 4     1997      5   19598019.0 1997-05-01  9.303552e+06  1.029447e+07
# 5     1997      6   17594350.0 1997-06-01  9.653446e+06  7.940904e+06
# 6     1997      7   14261348.0 1997-07-01  9.992054e+06  4.269294e+06
# ..     ...    ...          ...        ...           ...           ...
# 320   2023      9  172570477.0 2023-09-01  1.178723e+08  5.469815e+07
# 321   2023     10  240914358.0 2023-10-01  1.182109e+08  1.227034e+08
# 322   2023     11   90119779.0 2023-11-01  1.185608e+08 -2.844105e+07
# 323   2023     12  128496690.0 2023-12-01  1.188994e+08  9.597251e+06
# 324   2024      1  121343414.0 2024-01-01  1.192493e+08  2.094081e+06
#
# [323 rows x 6 columns]

# %%
i3=pd.concat([
    i2[['date','KG_LIQUIDO']].assign(tipo='real'   ).rename(columns={'KG_LIQUIDO':'KG'}),
    i2[['date','KG_fit'    ]].assign(tipo='regress').rename(columns={'KG_fit'    :'KG'})
    ])
i3
# Out:
#           date            KG     tipo
# 2   1997-03-01  7.505776e+06     real
# 3   1997-04-01  2.266018e+07     real
# 4   1997-05-01  1.959802e+07     real
# 5   1997-06-01  1.759435e+07     real
# 6   1997-07-01  1.426135e+07     real
# ..         ...           ...      ...
# 320 2023-09-01  1.178723e+08  regress
# 321 2023-10-01  1.182109e+08  regress
# 322 2023-11-01  1.185608e+08  regress
# 323 2023-12-01  1.188994e+08  regress
# 324 2024-01-01  1.192493e+08  regress
#
# [646 rows x 3 columns]

# %% [raw]
# sns.relplot(data=i3,x='date',y='KG',hue='tipo').fig.suptitle('Importação de Fertilizantes da Bahia',y=1.01)
# plt.show()

# %%
i2
# Out:
#     CO_ANO CO_MES   KG_LIQUIDO       date        KG_fit       KG_resi
# 2     1997      3    7505776.0 1997-03-01  8.615051e+06 -1.109275e+06
# 3     1997      4   22660177.0 1997-04-01  8.964945e+06  1.369523e+07
# 4     1997      5   19598019.0 1997-05-01  9.303552e+06  1.029447e+07
# 5     1997      6   17594350.0 1997-06-01  9.653446e+06  7.940904e+06
# 6     1997      7   14261348.0 1997-07-01  9.992054e+06  4.269294e+06
# ..     ...    ...          ...        ...           ...           ...
# 320   2023      9  172570477.0 2023-09-01  1.178723e+08  5.469815e+07
# 321   2023     10  240914358.0 2023-10-01  1.182109e+08  1.227034e+08
# 322   2023     11   90119779.0 2023-11-01  1.185608e+08 -2.844105e+07
# 323   2023     12  128496690.0 2023-12-01  1.188994e+08  9.597251e+06
# 324   2024      1  121343414.0 2024-01-01  1.192493e+08  2.094081e+06
#
# [323 rows x 6 columns]

# %%
i=i2

# %% [markdown]
# ### 2.Chuvas

# %%
# Importa as bibliotecas necessárias
# %run '~/git/Bibliotecas.ipynb'

# %%
c=pd.read_csv('/home/andre301267/git/Pricing-Fertilizer-take-Rains-into-account/temp/chuvas1.csv')

# %%
c=c[c.columns[[20,0,21,1,22,2]]]
c.columns=['Estação','date1','date2','hora1','hora2','mm']
c.date1=pd.to_datetime(c.date1+'-'+c.hora1)
c.date2=pd.to_datetime(c.date2+'-'+c.hora2)
c['date']=pd.to_datetime(pd.concat([c.date1.dropna(),c.date2.dropna()]), utc=True)
c['CO_ANO']=c.date.dt.year
c['CO_MES']=c.date.dt.month
c['Dia']=c.date.dt.day
c['Hora']=c.date.dt.hour
c.head(1)
# Out:
#      Estação      date1 date2  hora1 hora2 mm                      date  \
# 0  BARREIRAS 2002-01-01   NaT  00:00   NaN  0 2002-01-01 00:00:00+00:00
#
#    CO_ANO  CO_MES  Dia  Hora
# 0    2002       1    1     0

# %%
cc=c.copy()

# %% [markdown]
# # ATENÇÃO

# %%
c=cc.copy()

# %%
c=c[c.columns[[0,6,7,8,9,10,5]]]

# %%
c.loc[c.mm=='-9999','mm']=np.nan
c.mm=c.mm.str.replace(',','.')
c.mm=c.mm.astype('float')

# %%
c.duplicated().sum()
# Out:
# 0

# %%
c.isna().sum()
# Out:
# Estação         0
# date            0
# CO_ANO          0
# CO_MES          0
# Dia             0
# Hora            0
# mm         103001
# dtype: int64

# %%
c_na=c[(c.mm.isna())]
c_not_na=c[~(c.mm.isna())]

# %%
print(f"O número de registros sem valor dos mm corresponde a {round(100*len(c_na)/len(c))} % do total")
# Out:
# O número de registros sem valor dos mm corresponde a 19 % do total

# %%
c_na.isna().sum()
# Out:
# Estação         0
# date            0
# CO_ANO          0
# CO_MES          0
# Dia             0
# Hora            0
# mm         103001
# dtype: int64

# %% [raw]
# sns.displot(data=c_na.groupby('CO_ANO').CO_MES.count().reset_index(),x='CO_ANO').fig.suptitle('Chuvas no Oeste Baiano',y=1.01)
# plt.show()

# %% [raw]
# sns.displot(data=c_na.groupby('CO_MES').CO_ANO.count().reset_index(),x='CO_MES').fig.suptitle('Chuvas no Oeste Baiano',y=1.01)
# plt.show()

# %% [raw]
# sns.displot(data=c_na.groupby('Dia').CO_ANO.count().reset_index(),x='Dia').fig.suptitle('Chuvas no Oeste Baiano',y=1.01)
# plt.show()

# %% [raw]
# sns.displot(data=c_na.groupby('Hora').CO_ANO.count().reset_index(),x='Hora').fig.suptitle('Chuvas no Oeste Baiano',y=1.01)
# plt.show()

# %% [raw]
# sns.displot(data=c_na.groupby('Estação').CO_ANO.count().reset_index(),x='Estação').fig.suptitle('Chuvas no Oeste Baiano',y=1.01)
# plt.xticks(rotation=45)
# plt.show()

# %%
print(f"Dos registros sem NAN, apenas {round(100*len(c_not_na[c_not_na.mm!=0])/len(c_not_na))} % apresentam valor maior do que zero.")
# Out:
# Dos registros sem NAN, apenas 4 % apresentam valor maior do que zero.

# %%
c_dia=c_not_na.groupby(by=c_not_na.columns[[0,1,2,3,4]].tolist())[['mm']].sum().reset_index()
c_dia.head(1)
# Out:
#      Estação                      date  CO_ANO  CO_MES  Dia   mm
# 0  BARREIRAS 2001-12-20 15:00:00+00:00    2001      12   20  2.0

# %%
c_dia['mm_log']=np.log10(c_dia.mm)

# %% [raw]
# sns.displot(data=c_dia[c_dia.mm_log!=0],x='mm_log',log_scale=True, bins=4).fig.suptitle('Chuvas no Oeste Baiano',y=1.01)
# plt.show()

# %% [markdown]
# Veja acima que foi necessário calcular o logarítmo da medição em milímetro de chuva e ainda plotar em escala logarítmica para enfim conseguir visualizar a normalidade da distribuição, de tão ampla a distribuição real dos volumes ocorridos.

# %%
c_mes=c_dia.groupby(by=['Estação','CO_ANO','CO_MES']).mm.sum().reset_index()
c_mes
# Out:
#                     Estação  CO_ANO  CO_MES     mm
# 0                 BARREIRAS    2001      12   23.2
# 1                 BARREIRAS    2002       1    0.0
# 2                 BARREIRAS    2002       2    0.0
# 3                 BARREIRAS    2002       3   28.0
# 4                 BARREIRAS    2002       4   31.8
# ..                      ...     ...     ...    ...
# 656  LUIZ EDUARDO MAGALHAES    2023       8   20.0
# 657  LUIZ EDUARDO MAGALHAES    2023       9    1.2
# 658  LUIZ EDUARDO MAGALHAES    2023      10   81.2
# 659  LUIZ EDUARDO MAGALHAES    2023      11   74.4
# 660  LUIZ EDUARDO MAGALHAES    2023      12  101.0
#
# [661 rows x 4 columns]

# %%
c_mes['mm_log']=np.log10(c_mes.mm)

# %% [raw]
# sns.displot(data=c_mes[c_mes.mm>0],x='mm',log_scale=True,bins=5).fig.suptitle('Chuvas no Oeste Baiano',y=1.01)
# plt.show()

# %%
c=c_mes.groupby(by=['CO_ANO','CO_MES']).mm.median().reset_index()

# %% [raw]
# sns.displot(data=c[c.mm!=0],x='mm',log_scale=True,bins=6)
# plt.show()

# %%
c=c[c.mm>10**.1]

# %%
c['date']=pd.to_datetime(c.CO_ANO.astype(str)+'/'+c.CO_MES.astype(str)+'/1')
c
# Out:
#      CO_ANO  CO_MES    mm       date
# 0      2001      12  23.2 2001-12-01
# 3      2002       3  28.0 2002-03-01
# 4      2002       4  17.8 2002-04-01
# 5      2002       5  22.3 2002-05-01
# 6      2002       6   2.1 2002-06-01
# ..      ...     ...   ...        ...
# 252    2023       5  11.6 2023-05-01
# 255    2023       8  14.8 2023-08-01
# 257    2023      10  38.7 2023-10-01
# 258    2023      11  39.8 2023-11-01
# 259    2023      12  78.6 2023-12-01
#
# [171 rows x 4 columns]

# %%
c_ini=c.date.iloc[0]
c_fim=c.date.iloc[-1]

# %%
# Matriz Esparsa
c[['CO_ANO','CO_MES']]=c[['CO_ANO','CO_MES']].astype('category')
c=c.groupby(by=['CO_ANO','CO_MES']).mm.sum().reset_index()
c[['CO_ANO','CO_MES']]=c[['CO_ANO','CO_MES']].astype('int')
c['date']=pd.to_datetime(c.CO_ANO.astype(str)+'/'+c.CO_MES.astype(str)+'/1')
c=c[(c.date>=c_ini)&(c.date<=c_fim)]

# %%
c['date']=pd.to_datetime(c.CO_ANO.astype(str)+'/'+c.CO_MES.astype(str)+'/1')
c
# Out:
#      CO_ANO  CO_MES    mm       date
# 11     2001      12  23.2 2001-12-01
# 12     2002       1   0.0 2002-01-01
# 13     2002       2   0.0 2002-02-01
# 14     2002       3  28.0 2002-03-01
# 15     2002       4  17.8 2002-04-01
# ..      ...     ...   ...        ...
# 271    2023       8  14.8 2023-08-01
# 272    2023       9   0.0 2023-09-01
# 273    2023      10  38.7 2023-10-01
# 274    2023      11  39.8 2023-11-01
# 275    2023      12  78.6 2023-12-01
#
# [265 rows x 4 columns]

# %%
c=c.sort_values(by=['CO_ANO','CO_MES'])

# %%
c['mm_log']=0
c.loc[c.mm>0,'mm_log']=np.log10(c.mm)

# %% [markdown]
# # Junta imp com chuvas

# %% [raw]
# i1=i.copy()
# c1=c.copy()

# %%
i=i1.copy()
c=c1.copy()

# %%
i.columns
# Out:
# Index(['CO_ANO', 'CO_MES', 'KG_LIQUIDO', 'date', 'KG_fit', 'KG_resi'], dtype='object')

# %%
c.columns
# Out:
# Index(['CO_ANO', 'CO_MES', 'mm', 'date', 'mm_log'], dtype='object')

# %%
i_c=i.merge(c)

from sklearn.preprocessing import MinMaxScaler as mms
mms=mms()
i_c_mms=pd.DataFrame(mms.fit_transform(i_c[['KG_resi','mm','mm_log']]))
i_c_mms.columns=['kg_resi_mms','mm_mms','mm_log_mms']
i_c=pd.concat([i_c,i_c_mms],axis=1)
i_c.head(1)
# Out:
#    CO_ANO  CO_MES  KG_LIQUIDO       date        KG_fit        KG_resi    mm  \
# 0    2001      12  28011377.0 2001-12-01  2.820912e+07 -197747.917979  23.2
#
#      mm_log  kg_resi_mms    mm_mms  mm_log_mms
# 0  1.365488     0.322647  0.051056    0.513836

# %%
# Médias
kg_resi_m = i_c.groupby('CO_MES').kg_resi_mms.mean().reset_index().rename(columns={'kg_resi_mms':'kg_resi_mms_mean'})
mm_m      = i_c.groupby('CO_MES').mm_mms     .mean().reset_index().rename(columns={'mm_mms'     :'mm_mms_mean'     })
mm_log_m  = i_c.groupby('CO_MES').mm_log_mms .mean().reset_index().rename(columns={'mm_log_mms' :'mm_log_mms_mean' })

i_c=i_c.merge(kg_resi_m).merge(mm_m).merge(mm_log_m)
i_c.head(1)
# Out:
#    CO_ANO  CO_MES  KG_LIQUIDO       date        KG_fit        KG_resi    mm  \
# 0    2001      12  28011377.0 2001-12-01  2.820912e+07 -197747.917979  23.2
#
#      mm_log  kg_resi_mms    mm_mms  mm_log_mms  kg_resi_mms_mean  mm_mms_mean  \
# 0  1.365488     0.322647  0.051056    0.513836          0.268157     0.341281
#
#    mm_log_mms_mean
# 0         0.718193

# %%
# Diferencial
i_c['kg_resi_mms_dif'] = i_c.kg_resi_mms - i_c.kg_resi_mms_mean
i_c['mm_mms_dif']      = i_c.mm_mms      - i_c.mm_mms_mean
i_c['mm_log_mms_dif']  = i_c.mm_log_mms  - i_c.mm_log_mms_mean

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(i_c['mm_mms_dif'],i_c['kg_resi_mms_dif'])
# Out:
# 0.17098135833012526

# %%
for ad in range(13):
    kg=i_c[['kg_resi_mms_dif']]
    mm=i_c[['mm_mms_dif']]
    mm.index=mm.index+ad
    i_c_1=pd.concat([kg,mm],axis=1).dropna()
    print(f"Adiantando {ad} meses-Média de Erro Absoluto={round(100*metrics.mean_absolute_error(i_c_1['mm_mms_dif'],i_c_1['kg_resi_mms_dif']),1)}")
# Out:
# Adiantando 0 meses-Média de Erro Absoluto=17.1
# Adiantando 1 meses-Média de Erro Absoluto=16.1
# Adiantando 2 meses-Média de Erro Absoluto=15.8
# Adiantando 3 meses-Média de Erro Absoluto=15.7
# Adiantando 4 meses-Média de Erro Absoluto=15.6
# Adiantando 5 meses-Média de Erro Absoluto=16.5
# Adiantando 6 meses-Média de Erro Absoluto=15.9
# Adiantando 7 meses-Média de Erro Absoluto=16.4
# Adiantando 8 meses-Média de Erro Absoluto=15.0
# Adiantando 9 meses-Média de Erro Absoluto=16.0
# Adiantando 10 meses-Média de Erro Absoluto=16.0
# Adiantando 11 meses-Média de Erro Absoluto=16.4
# Adiantando 12 meses-Média de Erro Absoluto=16.7

# %%
# Produz i_c_l
a =i_c[['CO_ANO','CO_MES','date','kg_resi_mms_dif']].assign(tipo='kg_resi_mms_dif').rename(columns={'kg_resi_mms_dif':'mms_dif'})
b =i_c[['CO_ANO','CO_MES','date','mm_mms_dif'     ]].assign(tipo='mm_mms_dif'     ).rename(columns={'mm_mms_dif'     :'mms_dif'})
b1=i_c[['CO_ANO','CO_MES','date','mm_log_mms_dif' ]].assign(tipo='mm_log_mms_dif' ).rename(columns={'mm_log_mms_dif' :'mms_dif'})

# Introduz a linha média
m=b.copy()
m.mms_dif=0
m.tipo=''

i_c_l=pd.concat([a,b,b1,m])

# %%
i_c_l=i_c_l[i_c_l.tipo!='mm_log_mms_dif']

# %% [raw]
# sns.relplot(kind='line',data=i_c_l,x='CO_MES',y='mms_dif',hue='tipo', col='CO_ANO',col_wrap=5).fig.suptitle("Proporção entre Chuvas e Importação de Fertilizantes",y=1.01)
# plt.show()

# %%
i_c_l.tipo.unique()
# Out:
# array(['kg_resi_mms_dif', 'mm_mms_dif', ''], dtype=object)

# %%
a=i_c_l[i_c_l.tipo=='mm_mms_dif']
a.head(1)
# Out:
#    CO_ANO  CO_MES       date   mms_dif        tipo
# 0    2001      12 2001-12-01 -0.290225  mm_mms_dif

# %%
b=i_c_l[i_c_l.tipo!='mm_mms_dif']
b.head(1)
# Out:
#    CO_ANO  CO_MES       date  mms_dif             tipo
# 0    2001      12 2001-12-01  0.05449  kg_resi_mms_dif

# %%
a_ini=a.date.min()
a_fim=a.date.max()

a.CO_MES=a.CO_MES+7
for c in range(1,7+1):
    a.loc[a.CO_MES==12+c,'CO_ANO']=a.loc[a.CO_MES==12+c]['CO_ANO']+1
    a.loc[a.CO_MES==12+c,'CO_MES']=c

a=a[(a.date>=a_ini)&(a.date<=a_fim)]
b=b.merge(a[['CO_ANO','CO_MES']])
i_c_l=pd.concat([a,b])
i_c_l=i_c_l.dropna()
i_c_l.head(1)
# Out:
#    CO_ANO  CO_MES       date   mms_dif        tipo
# 0    2002       7 2001-12-01 -0.290225  mm_mms_dif

# %%
sns.relplot(kind='line',data=i_c_l,x='CO_MES',y='mms_dif',hue='tipo', col='CO_ANO',col_wrap=5,ci=None).fig.suptitle("Proporção entre Chuvas e Importação de Fertilizantes",y=1.01)
plt.show()
