# %% [markdown]
# # As chuvas influenciam a precificação dos fertilizantes?

# %%
from IPython.display import Image
Image("best.png")

# %% [markdown]
# Tratamento = Levar chuvas em conta na previsão de importação de fertilizantes

# %% [markdown]
# Responsável
# André Coutinho Bueno
# Cientista de Dados - Agrônomo
# cel:+55-21-99630-1267
# andrecoutinhobueno@hotmail.com
# https://github.com/AndreCoutinhoBueno
# https://www.linkedin.com/in/andre-coutinho-bueno/
# Rio de Janeiro - Brasil
