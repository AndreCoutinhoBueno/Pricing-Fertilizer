# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
n=imp_fert_ncm=pd.read_csv('~/git/BD/temp/imp_fert_ncm.csv')

# %%
pais=pd.read_csv('~/git/BD/Comexstat/tab_complementares/PAIS.csv',encoding='Latin-1', sep=';')

# %%
n=n.merge(pais[['CO_PAIS','NO_PAIS']])

# %%
n.loc[~n.NO_PAIS.isin(['Rússia','Canadá','China','Marrocos','Estados Unidos','Israel']),'NO_PAIS']='Outros'

# %%
n[n.NO_PAIS=='Outros'].groupby(by=['CO_NCM']).KG_LIQUIDO.sum().sort_values(ascending=False)
# Out:
# CO_NCM
# 31042090    75673501769
# 31021010    72808646608
# 31022100    22010333788
# 31031900     9443385834
# 31054000     8672683107
# 31052000     7273025912
# 31031030     4346276438
# 31029000     4164605573
# 31031010     3935609237
# 31024000     3839224115
# 31023000     2903185053
# 31055900     2047422263
# 31049090     1462532458
# 31059011     1395944901
# 31031100     1286006644
# 31026000     1282904180
# 31042010     1257114584
# 31043010     1198633975
# 31059019      964580863
# 31059090      762387909
# 31053010      414734061
# 31053000      396742416
# 31056000      270870345
# 31025011      210399582
# 31053090      134631750
# 31010000      121468947
# 31055100      112231560
# 31039090       91557849
# 31025090       82418215
# 31051000       70108744
# 31022910       54045803
# 31031020       38353910
# 31043090       32700257
# 31021090       31096181
# 31025019        5662972
# 31028000        1546710
# 31039019        1469151
# 31022990         545800
# ...

# %%
n=n.groupby(by=['CO_ANO','NO_PAIS'])[['KG_LIQUIDO','VL_FOB']].sum().reset_index()

# %%
sns.relplot(data=n,x='CO_ANO',y='KG_LIQUIDO',hue='NO_PAIS')
